# %%
import hvplot.pandas  # noqa
import tensorflow as tf
from argparse import Namespace
import tmodel
import hvplot as hv
tf.config.set_visible_devices([], 'GPU')             # disable GPU for this notebook
hv.extension('bokeh')

signal_index=2
feature_type=1
args: Namespace = tmodel.load_args(signal_index,feature_type)
nfs =  [8,10,12,14,16,24,32,64]

# %%
pgrid = tmodel.get_mnf_result_plots( args, nfs, ncols=3, psize=600 )
pgrid
