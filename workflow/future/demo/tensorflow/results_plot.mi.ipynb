# %%
import hvplot.pandas  # noqa
import tensorflow as tf
from argparse import Namespace
import tmodel
import hvplot as hv
tf.config.set_visible_devices([], 'GPU')             # disable GPU for this notebook
hv.extension('bokeh')

signal_index=2 # 2 68
feature_type=0
args: Namespace = tmodel.load_args(signal_index,feature_type)
args.ninstances = 8
args.nfeatures = 32
epoch_range_idx = 0

# %%
pgrid = tmodel.get_mi_result_plots(args, epoch_range_idx, ncols=4, psize=600 )
pgrid
